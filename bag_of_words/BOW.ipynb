# %% [markdown]
# ### BOW
# * O modelo de bag-of-words (BOW) é uma representação que transforma  texto (como uma frase ou um documento) arbitrário em vetores de comprimento fixo , contando a ocorrência das palavras .

# %%
import nltk
import re
import pandas as pd
from nltk.corpus import stopwords

# %%
paragraph  = "O Mestre na arte da vida faz pouca distinção entre o seu trabalho e o seu lazer, entre a sua mente e o seu corpo, entre a sua educação e a sua recreação, entre o seu amor e a sua religião. Ele dificilmente sabe distinguir um corpo do outro. Ele simplesmente persegue sua visão de excelência em tudo que faz, deixando para os outros a decisão de saber se está trabalhando ou se divertindo. Ele acha que está sempre fazendo as duas coisas simultaneamente."

# %%
sentences = nltk.sent_tokenize(paragraph )
for idx in range(len(sentences)):
    sentences[idx] = sentences[idx].lower()
    sentences[idx] = re.sub(r'\W',' ',sentences[idx])

# %%
word2count = {}
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    for word in words:
        if word not in stopwords.words('portuguese'):
            if word not in word2count.keys():
                word2count[word] = 1
            else:
                word2count[word] += 1

# %%
data = pd.DataFrame([[freq for freq in word2count.values()]], columns=[word for word in word2count.keys()]).T
data.rename(columns={0: 'BOW'}, inplace=True)

# %%
data.head(n=data.shape[0])
# Out:
#                  BOW
# mestre             1
# arte               1
# vida               1
# faz                2
# pouca              1
# distinção          1
# trabalho           1
# lazer              1
# mente              1
# corpo              2
# educação           1
# recreação          1
# amor               1
# religião           1
# dificilmente       1
# sabe               1
# distinguir         1
# outro              1
# simplesmente       1
# persegue           1
# visão              1
# excelência         1
# tudo               1
# deixando           1
# outros             1
# decisão            1
# saber              1
# trabalhando        1
# divertindo         1
# acha               1
# sempre             1
# fazendo            1
# duas               1
# coisas             1
# simultaneamente    1
